# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import neighbors, datasets
# Out:
# /home/ritik/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/ritik/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# /home/ritik/anaconda3/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
from matplotlib.colors import ListedColormap

def knn_camparision(data, n_neighbors = 15):
    """
    This fuction finds k-NN and plots the data.
    """
    
    x = data[:, :2]
    y = data[:, 2]
    
    # Grid cell size 
    h = 0.02
    cmap_light = ListedColormap(["#FFAAAA", "#AAAAFF"])
    cmap_bold = ListedColormap(["#FF0000", "#0000FF"])
    
    # the core classifier: k-NN
    clf = neighbors.KNeighborsClassifier(n_neighbors)
    clf.fit(x, y)
    
    x_min, x_max = x[:, 0].min() - 1, x[:, 0].max() + 1
    y_min, y_max = x[:, 1].min() - 1, x[:, 1].max() + 1
    
    # creating a mesh grid (x_min, y_min) to (x_max, y_max) woth 0.02 grid space
    xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
    
    # pridicte the value(either 0 or 1) of each element in the grid
    z = clf.predict(np.c_[xx.ravel(), yy.ravel()])
    
    z = z.reshape(xx.shape)
    
    plt.figure()
    plt.pcolormesh(xx, yy, z, cmap=cmap_light)
    
    plt.scatter(x[:, 0], x[:,1], c = y, cmap=cmap_bold)
    
    plt.xlim(xx.min(), xx.max())
    plt.ylim(yy.min(), yy.max())
    
    plt.title("K value = "+str(n_neighbors))
    
    plt.show

# %%
data = np.genfromtxt("demo_data/6.overlap.csv", delimiter=',')
knn_camparision(data, 1)
knn_camparision(data, 5)
knn_camparision(data, 15)
knn_camparision(data, 30)
knn_camparision(data, 50)

# %%
data = np.genfromtxt("demo_data/1.ushape.csv", delimiter=',')
knn_camparision(data, 1)
knn_camparision(data, 5)
knn_camparision(data, 15)
knn_camparision(data, 30)
knn_camparision(data, 50)

# %%
data = np.genfromtxt("demo_data/2.concerticcir1.csv", delimiter=',')
knn_camparision(data, 1)
knn_camparision(data, 5)
knn_camparision(data, 15)
knn_camparision(data, 30)
knn_camparision(data, 50)

# %%
data = np.genfromtxt("demo_data/3.concertriccir2.csv", delimiter=',')
knn_camparision(data, 1)
knn_camparision(data, 5)
knn_camparision(data, 15)
knn_camparision(data, 30)
knn_camparision(data, 50)

# %%
data = np.genfromtxt("demo_data/4.linearsep.csv", delimiter=',')
knn_camparision(data, 1)
knn_camparision(data, 5)
knn_camparision(data, 15)
knn_camparision(data, 30)
knn_camparision(data, 50)

# %%
data = np.genfromtxt("demo_data/5.outlier.csv", delimiter=',')
knn_camparision(data, 1)
knn_camparision(data, 5)

# %%
data = np.genfromtxt("demo_data/7.xor.csv", delimiter=',')
knn_camparision(data, 1)
knn_camparision(data, 5)
knn_camparision(data, 15)
knn_camparision(data, 30)
knn_camparision(data, 50)

# %%
data = np.genfromtxt("demo_data/8.twospirals.csv", delimiter=',')
knn_camparision(data, 1)
knn_camparision(data, 5)
# knn_camparision(data, 15)
# knn_camparision(data, 30)
# knn_camparision(data, 50)
